# %% [markdown]
# # Decaimento Radioativo
#
# Um problema recorrente é aquele do decaimento radioativo, onde um elemento decai para outro ao emitir radiação. Um modelo simples e eficiente para representar esse sistema físico é escrever a taxa de decaimento do material como sendo proporcional a quantidade dele que ainda não decaiu. Ou seja
#
# $$\frac{du}{dt}=- a u$$
#
# onde $u$ é a quantidade de material radioativo, $a$ é a taxa de decaimento radioativo e $t$ é o tempo. Podemos obter uma solução geral para esse problema apenas integrando a equação toda em relação ao tempo
#
# $$\ln{u}=at+C$$
#
# Impomos então a condição inicial de que $u(0)=u_0$ para eliminarmos a constante arbitrária $C$, isolamos $u$ e ficamos com
#
# $$u=u_0 e^{at}$$
#
# É interessante que tenhamos a solução analítica para compararmos com nossa aproximação numérica.

# %%
import numpy as np
import matplotlib.pyplot as plt

a=0.005
fig,ax=plt.subplots(figsize=(12,8))
ntt=[10,30,80,200]
for nt in ntt:
    t, dt=np.linspace(0,1000,nt,retstep=True)
    u=np.zeros((nt))
    u[0]=1.0
    for i in range(0,nt-1):
        u[i+1]=u[i]+dt*a*u[i]
    fig=plt.plot(t, u, '-', label=f"dt={dt:.2f}, NT={nt}")
fig=plt.plot(t,np.exp(a*t), label='Analítico')
leg=plt.legend()
